# %%
import glob,os,numpy as np,sys
#merfish11: S:\20230908_D106Luo\DNA\AnalysisDeconvolveCG
#merfish10: 
fls_dapi = glob.glob(r'S:\20230908_D106Luo\DNA\AnalysisDeconvolveCG\*')
#fl_targ = r'Q:\Carlos_Analysis\AnalysisDeconvolveCG'

# %%
import shutil
from tqdm import tqdm
for fl_dapi in tqdm(fls_dapi):
    fl_targ = fl_dapi.replace(r'S:\20230908_D106Luo\DNA',r'Q:\Carlos_Analysis')
    #print(fl_targ)
    if not os.path.exists(fl_targ):
        try:
            print("transfering" +str(fl_targ))
            shutil.copy2(fl_dapi,fl_targ)
        except:
            print("some stuff going on w... "+str(fl_targ))
# Out:
#  17%|████████████▎                                                             | 60555/362212 [02:24<15:35, 322.40it/s]
# transferingQ:\Carlos_Analysis\AnalysisDeconvolveCG\Conv_zscan__0423--H23_B67_68_69--dapiFeatures.npz
# transferingQ:\Carlos_Analysis\AnalysisDeconvolveCG\Conv_zscan__0908--H32_B94_95_96--col0__Xhfits.npz
# transferingQ:\Carlos_Analysis\AnalysisDeconvolveCG\Conv_zscan__0871--H36_B106_107_108--dapiFeatures.npz
# transferingQ:\Carlos_Analysis\AnalysisDeconvolveCG\Conv_zscan__0054--H11_B31_32_33--col2__Xhfits.npz
# transferingQ:\Carlos_Analysis\AnalysisDeconvolveCG\Conv_zscan__0054--H8_B22_23_24--col0__Xhfits.npz
# transferingQ:\Carlos_Analysis\AnalysisDeconvolveCG\Conv_zscan__0143--H38_B112_113_114--col0__Xhfits.npz
# transferingQ:\Carlos_Analysis\AnalysisDeconvolveCG\Conv_zscan__1139--H53_B157_158_159--col0__Xhfits.npz
# transferingQ:\Carlos_Analysis\AnalysisDeconvolveCG\Conv_zscan__0642--H116_B346_347_348--col0__Xhfits.npz
# ...

# %%
os.path.exists(r"S:\20230908_D106Luo\DNA\AnalysisDeconvolveCG\Conv_zscan__0257--H81_B241_242_243--dapiFeatures.npz")
# Out:
# True

# %%
fl_dapi
# Out:
# 'S:\\20230908_D106Luo\\DNA\\AnalysisDeconvolveCG\\Conv_zscan__0537--H15_B43_44_45--col0__Xhfits.npz'

# %%
lol = fl_dapi.replace(r'S:\20230908_D106Luo\DNA',r'Q:\Carlos_Analysis')

# %%
os.path.exists(lol)
# Out:
# True

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 2
#       1 import os
# ----> 2 os.get_cwd()
#
# AttributeError: module 'os' has no attribute 'get_cwd'
